# %% [markdown]
# # LABS-3: Systems Project
#
# In this notebook you will run a few cells to ensure that your environment is properly set up.

# %%
## First cell
# run this for step 11 in your instructions

print("Hello, World!")
# Out:
# Hello, World!

# %%
import pandas as pd

# %%
## Part 3: Accessing your data
# edit this code to load your data into your workspace

import pandas as pd
df = pd.read_csv('imdb_movies.csv')
df.head()
# Out:
#                  names       date_x  score                genre             overview  \
# 0            Creed III  03/02/2023    73.0        Drama, Action  After dominating...
# 1  Avatar: The Way ...  12/15/2022    78.0  Science Fiction,...  Set more than a ...
# 2  The Super Mario ...  04/05/2023    76.0  Animation, Adven...  While working un...
# 3              Mummies  01/05/2023    70.0  Animation, Comed...  Through a series...
# 4            Supercell  03/17/2023    61.0               Action  Good-hearted tee...
#
#                   crew           orig_title     status            orig_lang     budget_x  \
# 0  Michael B. Jorda...            Creed III   Released              English   75000000.0
# 1  Sam Worthington,...  Avatar: The Way ...   Released              English  460000000.0
# 2  Chris Pratt, Mar...  The Super Mario ...   Released              English  100000000.0
# 3  Óscar Barberán, ...               Momias   Released   Spanish, Castilian   12300000.0
# 4  Skeet Ulrich, Ro...            Supercell   Released              English   77000000.0
#
#         revenue country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US
